# %%
import sys

sys.path.append("../src")

from torch.utils.data import DataLoader
from minicamels import MiniCamels
from data import get_attrs
from data import CamelsDataset

# %%
ds = CamelsDataset(time_selection=slice("2000-01-01", "2010-12-31"))

# %%
ds.data
